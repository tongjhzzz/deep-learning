# %%
import torch

# %% [markdown]
# troch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0,...)
# 分别对应的是输入图像的通道数(彩色图像一般数3)， 输出图像的通道数， 卷积核尺寸， 卷积核移动的步长， 边缘填充。
# 前三个需要自己填，后面的参数参数都有默认参数，一般用到前五个参数

# %% [markdown]
# 不清楚去看官方文档：https://docs.pytorch.org/docs/2.14/generated/torch.nn.Conv2d.html#torch.nn.Conv2d

# %% [markdown]
# # torch.reshape()
# torch.reshape(input, shape) -> Tensor
