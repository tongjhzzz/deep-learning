# %%
import torch
print(torch.__version__)
print(torch.backends.mps.is_available())
print(torch.__file__)
# Out:
# 2.14.0
# True
# /Users/daxian/deep-learning/.venv/lib/python3.12/site-packages/torch/__init__.py
